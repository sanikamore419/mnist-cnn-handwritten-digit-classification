# %% [markdown]
# <a href="https://colab.research.google.com/github/sanikamore419/mnist-cnn-handwritten-digit-classification/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-2c3c7a85-a678-46ca-a6a0-b48bd0277d29" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2c3c7a85-a678-46ca-a6a0-b48bd0277d29">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
import json

os.makedirs('/root/.kaggle', exist_ok=True)

with open('kaggle.json', 'r') as f:
    kaggle_credentials = json.load(f)

os.environ['KAGGLE_USERNAME'] = kaggle_credentials['username']
os.environ['KAGGLE_KEY'] = kaggle_credentials['key']

# !chmod 600 /root/.kaggle/kaggle.json 2>/dev/null || true

# %%
# !kaggle datasets download -d hojjatk/mnist-dataset
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/hojjatk/mnist-dataset
# License(s): copyright-authors
# ...
# 100% 22.0M/22.0M [00:00<00:00, 174MB/s]

# %%
import zipfile
import os

zip_file = '/content/mnist-dataset.zip'
extract_path = '/content/mnist_dataset'

with zipfile.ZipFile(zip_file, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted successfully!")
print(os.listdir(extract_path))
# Out:
# Dataset extracted successfully!
# ['t10k-images.idx3-ubyte', 't10k-images-idx3-ubyte', 'train-labels.idx1-ubyte', 'train-images-idx3-ubyte', 't10k-labels-idx1-ubyte', 'train-images.idx3-ubyte', 'train-labels-idx1-ubyte', 't10k-labels.idx1-ubyte']

# %%
import os

dataset_path = "/content/mnist_dataset"

for root, dirs, files in os.walk(dataset_path):
    print("\nFolder:", root)
    print("Files:", files)
    print("Subfolders:", dirs)
# Out:
# Folder: /content/mnist_dataset
# Files: ['t10k-images.idx3-ubyte', 'train-labels.idx1-ubyte', 'train-images.idx3-ubyte', 't10k-labels.idx1-ubyte']
# Subfolders: ['t10k-images-idx3-ubyte', 'train-images-idx3-ubyte', 't10k-labels-idx1-ubyte', 'train-labels-idx1-ubyte']
#
# Folder: /content/mnist_dataset/t10k-images-idx3-ubyte
# Files: ['t10k-images-idx3-ubyte']
# Subfolders: []
#
# Folder: /content/mnist_dataset/train-images-idx3-ubyte
# Files: ['train-images-idx3-ubyte']
# Subfolders: []
#
# Folder: /content/mnist_dataset/t10k-labels-idx1-ubyte
# Files: ['t10k-labels-idx1-ubyte']
# Subfolders: []
#
# Folder: /content/mnist_dataset/train-labels-idx1-ubyte
# Files: ['train-labels-idx1-ubyte']
# Subfolders: []

# %%
import numpy as np
import os

dataset_path = "/content/mnist_dataset"


def find_file(name):
    """Find the actual file anywhere inside the dataset folder."""
    for root, dirs, files in os.walk(dataset_path):
        if name in files:
            return os.path.join(root, name)
    raise FileNotFoundError(f"{name} not found")


def load_images(filename):
    with open(filename, "rb") as f:
        data = np.frombuffer(f.read(), dtype=np.uint8)

    num_images = int.from_bytes(data[4:8], byteorder="big")
    rows = int.from_bytes(data[8:12], byteorder="big")
    cols = int.from_bytes(data[12:16], byteorder="big")

    return data[16:].reshape(num_images, rows, cols)


def load_labels(filename):
    with open(filename, "rb") as f:
        data = np.frombuffer(f.read(), dtype=np.uint8)

    num_labels = int.from_bytes(data[4:8], byteorder="big")

    return data[8:8 + num_labels]


# Find actual files
train_images_file = find_file("train-images-idx3-ubyte")
train_labels_file = find_file("train-labels-idx1-ubyte")
test_images_file = find_file("t10k-images-idx3-ubyte")
test_labels_file = find_file("t10k-labels-idx1-ubyte")


# Load dataset
x_train = load_images(train_images_file)
y_train = load_labels(train_labels_file)

x_test = load_images(test_images_file)
y_test = load_labels(test_labels_file)


print("Training images:", x_train.shape)
print("Training labels:", y_train.shape)
print("Testing images:", x_test.shape)
print("Testing labels:", y_test.shape)
# Out:
# Training images: (60000, 28, 28)
# Training labels: (60000,)
# Testing images: (10000, 28, 28)
# Testing labels: (10000,)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))

for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_train[i], cmap='gray')
    plt.title(f"Label: {y_train[i]}")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import numpy as np

unique, counts = np.unique(y_train, return_counts=True)

print("Digit distribution:")
for digit, count in zip(unique, counts):
    print(f"Digit {digit}: {count} images")
# Out:
# Digit distribution:
# Digit 0: 5923 images
# Digit 1: 6742 images
# Digit 2: 5958 images
# Digit 3: 6131 images
# Digit 4: 5842 images
# Digit 5: 5421 images
# Digit 6: 5918 images
# Digit 7: 6265 images
# Digit 8: 5851 images
# Digit 9: 5949 images

# %%
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

print("Training data shape:", x_train.shape)
print("Testing data shape:", x_test.shape)
# Out:
# Training data shape: (60000, 28, 28, 1)
# Testing data shape: (10000, 28, 28, 1)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.20.0

# %%
model = Sequential([

    # Convolution Layer 1
    Conv2D(32, (3, 3), activation='relu',
           input_shape=(28, 28, 1)),

    # Pooling Layer 1
    MaxPooling2D(pool_size=(2, 2)),

    # Convolution Layer 2
    Conv2D(64, (3, 3), activation='relu'),

    # Pooling Layer 2
    MaxPooling2D(pool_size=(2, 2)),

    # Flatten feature maps
    Flatten(),

    # Fully Connected Layer
    Dense(128, activation='relu'),

    # Dropout
    Dropout(0.5),

    # Output Layer
    Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ...

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("Model compiled successfully!")
# Out:
# Model compiled successfully!

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=10,
    batch_size=128,
    validation_split=0.1,
    verbose=1
)
# Out:
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 30s 67ms/step - accuracy: 0.9049 - loss: 0.3120 - val_accuracy: 0.9850 - val_loss: 0.0571
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 40s 66ms/step - accuracy: 0.9705 - loss: 0.1006 - val_accuracy: 0.9877 - val_loss: 0.0447
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 28s 66ms/step - accuracy: 0.9774 - loss: 0.0758 - val_accuracy: 0.9872 - val_loss: 0.0415
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 40s 65ms/step - accuracy: 0.9816 - loss: 0.0607 - val_accuracy: 0.9905 - val_loss: 0.0371
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 42s 67ms/step - accuracy: 0.9841 - loss: 0.0530 - val_accuracy: 0.9900 - val_loss: 0.0341
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 27s 64ms/step - accuracy: 0.9865 - loss: 0.0449 - val_accuracy: 0.9900 - val_loss: 0.0322
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 28s 66ms/step - accuracy: 0.9880 - loss: 0.0392 - val_accuracy: 0.9923 - val_loss: 0.0332
# Epoch 8/10
# ...

# %%
test_loss, test_accuracy = model.evaluate(
    x_test,
    y_test,
    verbose=0
)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Test Accuracy (%):", test_accuracy * 100)
# Out:
# Test Loss: 0.02328016236424446
# Test Accuracy: 0.9919999837875366
# Test Accuracy (%): 99.19999837875366

# %%
plt.figure(figsize=(8, 5))

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')

plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.show()

# %%
y_probability = model.predict(x_test)

y_pred = np.argmax(y_probability, axis=1)

print("Predictions generated successfully!")
print("First 20 predicted labels:")
print(y_pred[:20])

print("\nFirst 20 actual labels:")
print(y_test[:20])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# Predictions generated successfully!
# First 20 predicted labels:
# [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4]
#
# First 20 actual labels:
# [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4]

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(
    y_test,
    y_pred,
    digits=4
))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9929    0.9949    0.9939       980
#            1     0.9921    0.9982    0.9952      1135
#            2     0.9903    0.9922    0.9913      1032
#            3     0.9941    0.9931    0.9936      1010
#            4     0.9889    0.9969    0.9929       982
#            5     0.9866    0.9910    0.9888       892
#            6     0.9958    0.9885    0.9921       958
#            7     0.9884    0.9932    0.9908      1028
#            8     0.9969    0.9918    0.9943       974
#            9     0.9940    0.9792    0.9865      1009
#
#     accuracy                         0.9920     10000
#    macro avg     0.9920    0.9919    0.9919     10000
# weighted avg     0.9920    0.9920    0.9920     10000

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))

sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=range(10),
    yticklabels=range(10)
)

plt.title('Confusion Matrix - MNIST CNN')
plt.xlabel('Predicted Digit')
plt.ylabel('Actual Digit')

plt.show()

# %%
plt.figure(figsize=(10, 6))

for i in range(10):
    plt.subplot(2, 5, i + 1)

    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')

    plt.title(
        f"Actual: {y_test[i]}\nPredicted: {y_pred[i]}"
    )

    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
incorrect_indices = np.where(y_pred != y_test)[0]

print("Number of incorrect predictions:",
      len(incorrect_indices))
# Out:
# Number of incorrect predictions: 80

# %%
plt.figure(figsize=(10, 6))

for i, index in enumerate(incorrect_indices[:10]):
    plt.subplot(2, 5, i + 1)

    plt.imshow(
        x_test[index].reshape(28, 28),
        cmap='gray'
    )

    plt.title(
        f"Actual: {y_test[index]}\n"
        f"Predicted: {y_pred[index]}"
    )

    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
index = 100

image = x_test[index]

prediction = model.predict(
    image.reshape(1, 28, 28, 1),
    verbose=0
)

predicted_digit = np.argmax(prediction)

plt.imshow(image.reshape(28, 28), cmap='gray')
plt.title(
    f"Actual: {y_test[index]} | "
    f"Predicted: {predicted_digit}"
)
plt.axis('off')
plt.show()

# %%
model.save('/content/mnist_cnn_model.keras')

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
print("========== CNN PERFORMANCE ==========")
print(f"Test Loss     : {test_loss:.4f}")
print(f"Test Accuracy : {test_accuracy:.4f}")
print(f"Accuracy (%)  : {test_accuracy * 100:.2f}%")
print("=====================================")
# Out:
# ========== CNN PERFORMANCE ==========
# Test Loss     : 0.0233
# Test Accuracy : 0.9920
# Accuracy (%)  : 99.20%
# ...
